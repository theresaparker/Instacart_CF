# %% [markdown]
# # Task 4.9 Data Visualization - Section 1

# %% [markdown]
# ## Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Question 3: Import your analysis libraries, as well as your new customer data set as a dataframe.

# %% [markdown]
# ## Importing dataset

# %%
# creating path
path = r'C:\Users\littl\Career Foundry\06.2022 Instacart Basket Analysis\02 - Data'

# %%
# importing customer data set
df = pd.read_csv(os.path.join(path,'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# ## Overview of dataset

# %%
df.head(15)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
df.shape
# Out:
# (206209, 10)

# %%
df.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # Question 4: Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %% [markdown]
# ## Data wrangling

# %%
# renaming columns to be consistent
df.rename(columns = {'user_id':'customer_id', 'First Name':'first_name', 'Surnam':'last_name', 'Gender':'gender', 'STATE':'state', 'Age':'age','n_dependents':'number_dependants'}, inplace = True)

# %%
df.head()
# Out:
#    customer_id first_name last_name  gender       state  age date_joined  \
# 0        26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1        33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2        65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3       125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4       130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# renaming columns continued
df.rename(columns = {'n_dependents':'#_of_dependents', 'fam_status':'marital_status'}, inplace = True)

# %%
df.rename(columns = {'n_dependants':'#_of_dependants'}, inplace = True)

# %%
df.head()
# Out:
#    customer_id first_name last_name  gender       state  age date_joined  \
# 0        26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1        33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2        65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3       125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4       130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    #_of_dependants marital_status  income
# 0                3        married  165665
# 1                0         single   59285
# 2                2        married   99568
# 3                0         single   42049
# 4                1        married   40374

# %% [markdown]
# NOTE:  I did not see any columns that needed to be removed at this time; however, If I were to remove a column, I would create a new dataframe and use the following syntax (df2 = df.drop(columns = ['column name'])

# %% [markdown]
# # Question 5: Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %% [markdown]
# ## Data Quality & Consistency

# %% [markdown]
# ### data types

# %%
# checking data types of columns
df.dtypes
# Out:
# customer_id         int64
# first_name         object
# last_name          object
# gender             object
# state              object
# age                 int64
# date_joined        object
# #_of_dependants     int64
# marital_status     object
# income              int64
# dtype: object

# %%
# checking for mixed data types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# reassigning mixed data type for 'first_name' to a string.
df['first_name'] = df['first_name'].astype('str')

# %%
# rechecking for mixed data types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %% [markdown]
# ### missing values

# %%
# checking for missing vlues
df.isnull().sum()
# Out:
# customer_id        0
# first_name         0
# last_name          0
# gender             0
# state              0
# age                0
# date_joined        0
# #_of_dependants    0
# marital_status     0
# income             0
# dtype: int64

# %% [markdown]
# --There are no missing values.

# %% [markdown]
# ### check for duplicates

# %%
# checking number of rows before removing duplicates
df.shape
# Out:
# (206209, 10)

# %%
# checking for duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, state, age, date_joined, #_of_dependants, marital_status, income]
# Index: []

# %% [markdown]
# -- There are no duplicates

# %% [markdown]
# ### check final output

# %%
df.head(20)
# Out:
#     customer_id first_name last_name  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5        133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6        152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7        168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8         69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9         82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10        26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# ...

# %% [markdown]
# # Question 6. Combine customer data with prepared Instacart data

# %%
# adding orders_products_merged dataset
ords_prods_merged = pd.read_pickle(os.path.join(path,'Prepared Data', '4.8_orders_products_merged.pkl'))

# %%
ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32406036   1320836   202557    prior            17          2
# 32406037     31526   202557    prior            18          5
# 32406038    758936   203436    prior             1          2
# 32406039   2745165   203436    prior             2          3
# 32406040   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %% [markdown]
# ### key column will be customer_id

# %%
# changing column name user_id to customer_id so the two datasets match
ords_prods_merged.rename(columns = {'user_id':'customer_id'}, inplace = True)

# %% [markdown]
# ### checking data types for key columns

# %%
# checking data type for key column in ords_prods_merged
ords_prods_merged['customer_id'].dtype
# Out:
# dtype('int64')

# %%
# checking data type for key column in df
df['customer_id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### merging datasets

# %%
# merging customer dataset and orders_products_merged dataset
df_full_merge = ords_prods_merged.merge(df, on = 'customer_id')

# %%
# check output
df_full_merge
# Out:
#           order_id  customer_id eval_set  order_number  order_dow  \
# 0          2539329            1    prior             1          2
# 1          2398795            1    prior             2          3
# 2           473747            1    prior             3          3
# 3          2254736            1    prior             4          4
# 4           431534            1    prior             5          4
# ...            ...          ...      ...           ...        ...
# 32406036    156685       106143    prior            26          4
# 32406037    484769        66343    prior             1          6
# 32406038   1561557        66343    prior             2          1
# 32406039    276317        66343    prior             3          6
# 32406040   2922475        66343    prior             4          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %% [markdown]
# ### cleaning the merged dataset

# %%
# renaming 'order_dow' to make more sense
df_full_merge.rename(columns = {'order_dow':'order_day_of_week'}, inplace = True)

# %%
df_full_merge.head()
# Out:
#    order_id  customer_id eval_set  order_number  order_day_of_week  \
# 0   2539329            1    prior             1                  2
# 1   2398795            1    prior             2                  3
# 2    473747            1    prior             3                  3
# 3   2254736            1    prior             4                  4
# 4    431534            1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...     Most Orders first_name  last_name  gender    state age  \
# ...

# %% [markdown]
# # Question 8: Export this new dataframe as a pickle file so you can continue to use it in the second part of this task.

# %%
# exporting fully merged dataset
df_full_merge.to_pickle(os.path.join(path, 'Prepared Data', '4.9_full_merge.pkl'))
