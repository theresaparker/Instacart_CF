# %% [markdown]
# # Task 4.6 - Combing and Exporting Data

# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# creating path
path = r'C:\Users\littl\Career Foundry\06.2022 Instacart Basket Analysis\02 - Data'

# %%
path
# Out:
# 'C:\\Users\\littl\\Career Foundry\\06.2022 Instacart Basket Analysis\\02 - Data'

# %%
# importing orders_products_combined pkl file
df_orders_products = pd.read_pickle(os.path.join(path,'Prepared Data', 'orders_products_combined.pkl'))

# %%
# checking output
df_orders_products.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_orders_products.shape
# Out:
# (32434489, 11)

# %%
# importing 4.5_products_cleaned.csv
df_products = pd.read_csv(os.path.join(path, 'Prepared Data','4.5_products_cleaned.csv'), index_col = False)

# %%
# checking output
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products.shape
# Out:
# (49677, 6)

# %% [markdown]
# ### Question 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %% [markdown]
# -Please see above in the Importing Data section.

# %% [markdown]
# ### Question 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %% [markdown]
# -Please see above in the Importing Data section.  This matches.

# %% [markdown]
# # Merging Data

# %% [markdown]
# ### Question 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %% [markdown]
# -First step is to import the 4.5_products_cleaned.csv.  Please see above in the Importing Data Section.

# %% [markdown]
# - Due to the dataframes not being the same in rows or column length this is best to do an inner join. Before merging we want to remove the -merge column as that is going to be added in again with our merge.

# %%
# creating a new list to remove the _merge column from df_prodcuts
df_orders_products2 = df_orders_products.drop(columns = ['_merge'])

# %%
# check output
df_orders_products2.head(
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
# Test merging df_orders_prodcuts2 with df_products
pd.merge(df_orders_products2,df_products, on = ['product_id'], indicator = True)
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32406036   1320836   202557    prior            17          2
# 32406037     31526   202557    prior            18          5
# 32406038    758936   203436    prior             1          2
# 32406039   2745165   203436    prior             2          3
# 32406040   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
# Merging 
df_orders_products2_merged = df_orders_products2.merge(df_products, on = 'product_id', indicator = True)

# %%
# check output
df_orders_products2_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %%
# shape
df_orders_products2_merged.shape
# Out:
# (32406041, 16)

# %%
# checking value_counts for full match
df_orders_products2_merged['_merge'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Question 6. Confirm the results of the merge using the merge flag.

# %% [markdown]
# -- See line 18 for the merge flag

# %% [markdown]
# # Exporting Data

# %% [markdown]
# ### Question 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# exporting to pkl

df_orders_products2_merged.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))
